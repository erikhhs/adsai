# %%
import adsai.functions
help(adsai)
# Out:
# Help on package adsai:
#
# NAME
#     adsai
#
# PACKAGE CONTENTS
#     functions
#
# FILE
#     c:\users\ejvdham\de haagse hogeschool\bachelor applied datascience_groups - general\1-voltijd\onderwijsontwikkeling\semester 2\3. programmeren voor data-analyse basis ii\packages\adsai\__init__.py

# %%
adsai.functions.print_hi()
# Out:
# hi

# %%
import adsai

# %%
adsai.print_hi()
# Out:
# hi

# %% [markdown]
# Om kernels te kunnen switchen in notebook, in base environment:
# ![image-5.png](attachment:image-5.png)
# Create nieuwe environment:
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd

tr15 = pd.read_csv('tr15.csv')
tr15.head()
# Out:
#          date  year  window int/ext  within_league season  \
# 0  2015-07-01  2015       1       E          False  15/16
# 1  2015-08-12  2015       1       E          False  15/16
# 2  2015-08-03  2015       1       I           True  15/16
# 3  2015-08-27  2015       1       I           True  15/16
# 4  2015-07-01  2015       1       I          False  15/16
#
#            player_name            position from_country     from_league  ...  \
# 0           Orlando Sá      Centre-Forward       Poland     Ekstraklasa  ...
# 1        Paolo Hurtado  Attacking Midfield     Portugal   Primeira Liga  ...
# 2  Alireza Jahanbakhsh        Right Winger  Netherlands      Eredivisie  ...
# 3         Ben Rienstra    Central Midfield  Netherlands      Eredivisie  ...
# 4      Vincent Janssen      Centre-Forward  Netherlands  Jupiler League  ...
#
#          team age_transfer market value fee amount  duration_cleaned  \
# 0  Reading FC           27          1.5       1.50              23.0
# ...

# %%
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import adsai.functions

# %%
help(adsai.functions)
# Out:
# Help on module adsai.functions in adsai:
#
# NAME
#     adsai.functions
#
# FUNCTIONS
#     col_to_list(df, col)
#
#     print_hi()
#
# FILE
#     c:\users\ejvdham\de haagse hogeschool\bachelor applied datascience_groups - general\1-voltijd\onderwijsontwikkeling\semester 2\3. programmeren voor data-analyse basis ii\packages\adsai\functions.py

# %%
adsai.functions.col_to_list(tr15,'player_name')
# Out:
# ['Orlando Sá',
#  'Paolo Hurtado',
#  'Alireza Jahanbakhsh',
#  'Ben Rienstra',
#  'Vincent Janssen',
#  'Rajko Brezancic',
#  'Virgil van Dijk',
#  'Jordy Clasie',
#  'Cédric Soares',
#  'Juanmi',
#  'Oriol Romeu',
#  'Fernando Forestieri',
#  'Lucas João',
#  'Rhoys Wiggins',
#  'Lewis McGugan',
#  'Guillermo Cotugno',
#  'Maksim Batov',
#  'Albert Sharipov',
#  'Jordan Ayew',
#  'Jordan Amavi',
#  'Jordan Veretout',
#  'Adama Traoré',
#  'Idrissa Gueye',
#  'Rudy Gestede',
#  'Scott Sinclair',
#  'Joleon Lescott',
#  'José Crespo',
#  'Baptiste Guillaume',
#  'Eric Bauthéac',
#  'Ibrahim Amadou',
#  'Lenny Nangis',
#  'Yassine Benzia',
#  'Junior Tallo',
#  'Mike Maignan',
#  'Serhou Guirassy',
#  'Mickaël Le Bihan',
#  'Jean Michaël Seri',
#  'Maxime Le Marchand',
#  'Naby Sarr',
#  'Patrick Bauer',
#  'El-Hadji Ba',
#  'Zakarya Bergdich',
#  'Elias Kachunga',
#  'Markus Suttner',
#  'Maurice Multhaup',
#  'Nemanja Gudelj',
#  'Arkadiusz Milik',
#  'Amin Younes',
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
